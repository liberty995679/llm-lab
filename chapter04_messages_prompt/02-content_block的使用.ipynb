# %% [markdown]
# # content的使用
# 举例1：保存多模态的数据，使用字典列表

# %%
import base64
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage

load_dotenv(override=True)

ALIYUN_API_KEY = os.getenv("DASHSCOPE_API_KEY")
ALIYUN_BASE_URL = os.getenv("ALIYUN_BASE_URL")

model = init_chat_model(
    model= "qwen-vl-plus",
    model_provider="openai",
    api_key = ALIYUN_API_KEY,
    base_url = ALIYUN_BASE_URL
)


def encode_image(img_path, img_type='png'):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode("utf-8")}"

# 图像路径
img_path = "image_test.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path,img_type="png")

response = model.invoke(
    [
        HumanMessage(
            content=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image_url',
                    "image_url": {"url": base64_image},
                }
            ]
        )
    ]
)
print(response.content)
# Out:
# 这张图片展示了一幅壮丽的自然景观。以下是对图片中内容的详细描述：
#
# 1. **山脉**：
#    - 图片两侧是高耸的山脉，山体陡峭，覆盖着茂密的绿色植被。
#    - 山脉的轮廓在阳光的照射下显得非常清晰，部分山峰被云雾缭绕，增加了画面的层次感和神秘感。
#
# 2. **河流**：
#    - 一条宽阔的河流蜿蜒穿过山谷，河水呈现出深绿色，反射着阳光，形成耀眼的光斑。
#    - 河流的水面平静，只有几艘船只在上面航行，留下淡淡的波纹。
#
# 3. **船只**：
#    - 图片中有几艘船只在河面上行驶，它们的大小不一，分布在不同的位置。
#    - 这些船只的存在为画面增添了一些动态元素，显示出人类活动与自然景观的和谐共存。
#
# 4. **天空**：
#    - 天空中有厚厚的云层，阳光从云层的缝隙中穿透出来，形成美丽的光束效果。
#    - 云层的颜色从白色到灰色不等，增加了画面的深度和质感。
#
# 5. **光影效果**：
#    - 阳光在河面上形成了明亮的反光，使得整个画面显得非常生动。
#    - 山脉的阴影部分与阳光照射的部分形成了鲜明的对比，增强了画面的立体感。
#
# 6. **整体氛围**：
#    - 整个画面给人一种宁静、壮丽的感觉，仿佛置身于一个远离尘嚣的世外桃源。
#    - 自然景观的宏伟与人类活动的微小形成了鲜明的对比，突显了大自然的壮美。
#
# 这张图片通过细腻的构图和光影处理，成功地捕捉到了大自然的美丽与宁静，令人叹为观止。

# %% [markdown]
# # content_block的使用
# 举例1：输入的格式化

# %%
import base64
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage

load_dotenv(override=True)

ALIYUN_API_KEY = os.getenv("DASHSCOPE_API_KEY")
ALIYUN_BASE_URL = os.getenv("ALIYUN_BASE_URL")

model = init_chat_model(
    model= "qwen-vl-plus",
    model_provider="openai",
    api_key = ALIYUN_API_KEY,
    base_url = ALIYUN_BASE_URL
)


def encode_image(img_path, img_type='png'):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode("utf-8")}"

# 图像路径
img_path = "image_test.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path,img_type="png")

response = model.invoke(
    [
        HumanMessage(
            content_blocks=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image_url',
                    "image_url": {"url": base64_image},
                }
            ]
        )
    ]
)
print(response.content)
# Out:
# 这张图片展示了一幅壮丽的自然景观，具体描述如下：
#
# 1. **河流**：画面中央是一条宽阔的河流，河水呈现出深绿色，反射着阳光，显得波光粼粼。河流蜿蜒穿过山谷，给人一种宁静而深远的感觉。
#
# 2. **山脉**：河流两侧是高耸的山脉，山体陡峭，覆盖着茂密的绿色植被。山峰在云雾中若隐若现，增加了画面的层次感和神秘感。
#
# 3. **船只**：河面上有几艘船只正在航行，它们在阳光的照射下显得格外醒目。这些船只可能是游船或货船，为这幅自然景观增添了一丝人文气息。
#
# 4. **天空**：天空中布满了云层，阳光从云层间隙中透出，形成美丽的光束效果。这种光影效果使得整个画面更加生动和富有层次感。
#
# 5. **整体氛围**：整幅画面给人一种宁静、壮丽的感觉，仿佛置身于大自然的怀抱中，令人心旷神怡。
#
# 这张图片可能拍摄于某个著名的峡谷或河流景区，如中国的长江三峡等地方，展现了大自然的鬼斧神工和人类活动的和谐共存。
