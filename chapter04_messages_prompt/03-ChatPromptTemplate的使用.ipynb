# %% [markdown]
# # 1.ChatPromptTemplate的实例化
# ## 1.1 from_messages()
# ### 1.1.1 创建一个ChatPromptTemplate实例，使用from_messages()方法 推荐
# 举例

# %%
from langchain_core.messages import SystemMessage
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

result = chat_prompt_template.invoke({"name": "小智", "user_input": "2 + 2 = ?"})

print(result)
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### 1.2 使用实例初始化方法
# 举例

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

result = chat_prompt_template.invoke({"name": "小智", "user_input": "2 + 2 = ?"})

print(result)
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## 2、ChatPromptTemplate的调用方法
# ### 2.1 invoke()
#
# 传入参数：字典列表，返回值类型为ChatPromptValue
# 举例

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

result = chat_prompt_template.invoke({"name": "小智", "user_input": "2 + 2 = ?"})

print(result)
print(type(result))
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %% [markdown]
# ### 2.2 format()
#
# 参数类型：变量值，返回值类型为ChatPromptValue
#
# 举例

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

# 调用
result = chat_prompt_template.format(name="小智", user_input="2 + 2 = ?")
print(result)
print(type(result))
# Out:
# System: 你是一个友好的AI助手，你的名字叫小智
# Human: 你好，最近怎么样？
# AI: 我很好，谢谢
# Human: 2 + 2 = ?
# <class 'str'>

# %% [markdown]
# ### 2.3 format_messages()
#
# 传入参数：变量值；返回值类型为消息列表
#
# 举例

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

result = chat_prompt_template.format_messages(name="小智",user_input="2 + 2 = ?")
print(result)
print(type(result))
# Out:
# [SystemMessage(content='你是一个友好的AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ?', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %% [markdown]
# ## 结合大模型的调用
# 举例

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model= "deepseek-v4-flash",
    api_key = DEEPSEEK_API_KEY,
    base_url = DEEPSEEK_BASE_URL
)

# 提示词模版
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手，你的名字叫{name}"),
    ("human", "你好，最近怎么样？"),
    ("ai", "我很好，谢谢"),
    ("human", "{user_input}")
])

prompt_value = chat_prompt_template.invoke({"name": "小智", "user_input": "2 + 2 = ?"})

# 模型调用
response = model.invoke(prompt_value)
print(response)
# Out:
# content='2 + 2 = 4 呀！这个很简单，不过要是有什么更难的数学题，或者需要我帮忙分析、聊天，随时都可以找我哦~ 😊' additional_kwargs={'refusal': None, 'reasoning_content': '1.  **分析用户的输入**：\n    *   用户问候：“你好，最近怎么样？”（最初的问候）。\n    *   用户提问：“2 + 2 = ?”（一个简单的数学问题）。\n    *   我的身份：“你是一个友好的AI助手，你的名字叫小智”（你是一个友好的AI助手，你的名字叫小智）。\n    *   我对最初问候的回复：“我很好，谢谢”（表达了良好状态）。\n\n2.  **确定目标**：回答“2 + 2 = ?”这个数学问题，同时保持友好助手的个性（小智）。\n\n3.  **制定回复**：\n    *   直接回答数学问题：2 + 2 = 4。\n    *   保持友好和助人的语气。\n    *   保持中文，与用户输入和设定的身份（小智）一致。'} response_metadata={'token_usage': {'completion_tokens': 210, 'prompt_tokens': 113, 'total_tokens': 323, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 173, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 113}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': '70569f00-f824-4343-9616-54761eb4fa88', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fb7a5-4a2c-71d3-8966-2493552d4be8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 113, 'output_tokens': 210, 'total_tokens': 323, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 173}}

# %% [markdown]
# ## 更丰富的初始化参数类型
# ### 4.1 字符串列表

# %%
chat_prompt_template = ChatPromptTemplate.from_messages([
    "你好，我是{name}"
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.2 元组列表

# %%
chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个友好的AI助手"),
    ("human","你好，我是{name}")
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个友好的AI助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## 4.3 字典列表

# %%
chat_prompt_template = ChatPromptTemplate.from_messages([
    {"role": "system", "content": "你是一个友好的AI助手"},
    {"role": "user", "content": "你好，我是{name}"}
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个友好的AI助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## 4.4 消息对象列表

# %%
from langchain.messages import SystemMessage,HumanMessage
chat_prompt_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="你是一个友好的AI助手"),
    HumanMessage(content="你好，我是{name}")
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个友好的AI助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是{name}', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.5 BaseMessagePromptTemplate参数列表

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate

system_mess_template = SystemMessagePromptTemplate.from_template("你是一个友好的AI助手")

human_mess_template = HumanMessagePromptTemplate.from_template("你好，我是{name}")

chat_prompt_template = ChatPromptTemplate.from_messages([
    system_mess_template,
    human_mess_template
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个友好的AI助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## 4.6 BaseChatPromptTemplate参数列表

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate

inner_chat_template1 = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手")
])

inner_chat_template2 = ChatPromptTemplate.from_messages([
    ("human","你好，我是{name}")
])

chat_prompt_template = ChatPromptTemplate.from_messages([
    inner_chat_template1,
    inner_chat_template2
])

chat_prompt_template.invoke({"name": "小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个友好的AI助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])
